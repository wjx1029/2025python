# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
class SimpleMLP(nn.Module):
    def __init__(self):
        super(SimpleMLP, self).__init__()

        # 第一层全连接层，输入784（28x28图像），输出256
        self.fc1 = nn.Linear(784, 256)

        # 第二层全连接层，输入256，输出128
        self.fc2 = nn.Linear(256, 128)

        # 第三层全连接层，输入128，输出10（类别数）
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        # x.shape = (b, 1, 28, 28)
        
        # 将图像展平为一维向量
        x = torch.flatten(x, 1)
        # x.shape = (b, 784)

        # 第一层全连接后使用ReLU激活函数
        x = F.relu(self.fc1(x))

        # 第二层全连接后使用ReLU激活函数
        x = F.relu(self.fc2(x))

        # 第三层全连接输出
        x = self.fc3(x)
        # x.shape = (b, 10)

        # 在使用nn.CrossEntropyLoss时，不需要在这里应用Softmax
        return x

# %%
def main():
    # 加载 MNIST 训练集
    # 参数：数据集的本地路径、使用训练集还是测试集、是否自动下载数据集、数据预处理流程
    train_dataset = datasets.MNIST(
        root='./data',
        train=True, 
        download=True, 
        transform=transforms.ToTensor()
    )
    
    # 从数据集创建DataLoader
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    model = SimpleMLP()
    
    # 分类问题，使用交叉熵损失函数
    loss_func = nn.CrossEntropyLoss()

    optimizer = optim.SGD(model.parameters(), lr=0.01)

    # 设置网络为训练模式
    model.train()

    for epoch in range(5):  # 总共训练5轮
        # 本轮训练的平均loss
        train_loss = 0

        # enumerate用法：https://www.runoob.com/python/python-func-enumerate.html
        for batch_idx, (data, target) in enumerate(train_loader):
            # data.shape = (b, 1, 28, 28)
            # target.shape = (b, 10)

            # 将网络中的梯度清零
            optimizer.zero_grad()

            # 进行一次推理
            output = model(data)
            # output.shape = (b, 10)

            # 调用损失函数，计算损失值
            loss = loss_func(output, target)
            train_loss += loss.item()

            # 反向传播，计算loss的梯度
            loss.backward()

            # 使用网络中的梯度更新参数
            optimizer.step()

            # 每100次循环打印一次
            if batch_idx % 100 == 0:
                print(f"训练轮次: {epoch + 1} [{batch_idx * len(data)}/{len(train_loader.dataset)}] 损失: {loss.item():.6f}")
        
        print(f"================ 训练轮次: {epoch + 1} 平均损失: {train_loss / len(train_loader):.6f} ================\n")

# %%
if __name__ == '__main__':
    main()
# Out:
# 100%|██████████| 9.91M/9.91M [00:16<00:00, 593kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 127kB/s]
# 100%|██████████| 1.65M/1.65M [00:03<00:00, 474kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 2.17MB/s]
# 训练轮次: 1 [0/60000] 损失: 2.294795
# 训练轮次: 1 [3200/60000] 损失: 2.270741
# 训练轮次: 1 [6400/60000] 损失: 2.240847
# 训练轮次: 1 [9600/60000] 损失: 2.134389
# 训练轮次: 1 [12800/60000] 损失: 2.052396
# 训练轮次: 1 [16000/60000] 损失: 1.788926
# 训练轮次: 1 [19200/60000] 损失: 1.566287
# 训练轮次: 1 [22400/60000] 损失: 1.200347
# 训练轮次: 1 [25600/60000] 损失: 0.985298
# 训练轮次: 1 [28800/60000] 损失: 0.767695
# 训练轮次: 1 [32000/60000] 损失: 0.745834
# 训练轮次: 1 [35200/60000] 损失: 0.728598
# 训练轮次: 1 [38400/60000] 损失: 0.641983
# 训练轮次: 1 [41600/60000] 损失: 0.567748
# 训练轮次: 1 [44800/60000] 损失: 0.412498
# 训练轮次: 1 [48000/60000] 损失: 0.365785
# 训练轮次: 1 [51200/60000] 损失: 0.373610
# 训练轮次: 1 [54400/60000] 损失: 0.284984
# 训练轮次: 1 [57600/60000] 损失: 0.314897
# ================ 训练轮次: 1 平均损失: 1.145141 ================
#
# 训练轮次: 2 [0/60000] 损失: 0.469318
# 训练轮次: 2 [3200/60000] 损失: 0.654998
# 训练轮次: 2 [6400/60000] 损失: 0.513364
# 训练轮次: 2 [9600/60000] 损失: 0.251059
# 训练轮次: 2 [12800/60000] 损失: 0.226139
# 训练轮次: 2 [16000/60000] 损失: 0.375099
# 训练轮次: 2 [19200/60000] 损失: 0.379581
# 训练轮次: 2 [22400/60000] 损失: 0.344586
# 训练轮次: 2 [25600/60000] 损失: 0.239926
# 训练轮次: 2 [28800/60000] 损失: 0.457950
# 训练轮次: 2 [32000/60000] 损失: 0.113819
# 训练轮次: 2 [35200/60000] 损失: 0.273482
# 训练轮次: 2 [38400/60000] 损失: 0.319055
# 训练轮次: 2 [41600/60000] 损失: 0.303131
# 训练轮次: 2 [44800/60000] 损失: 0.439056
# 训练轮次: 2 [48000/60000] 损失: 0.466760
# 训练轮次: 2 [51200/60000] 损失: 0.357474
# 训练轮次: 2 [54400/60000] 损失: 0.257195
# 训练轮次: 2 [57600/60000] 损失: 0.245586
# ================ 训练轮次: 2 平均损失: 0.370362 ================
#
# 训练轮次: 3 [0/60000] 损失: 0.396053
# 训练轮次: 3 [3200/60000] 损失: 0.188089
# 训练轮次: 3 [6400/60000] 损失: 0.152086
# 训练轮次: 3 [9600/60000] 损失: 0.391227
# 训练轮次: 3 [12800/60000] 损失: 0.319830
# 训练轮次: 3 [16000/60000] 损失: 0.225252
# 训练轮次: 3 [19200/60000] 损失: 0.348430
# 训练轮次: 3 [22400/60000] 损失: 0.216878
# 训练轮次: 3 [25600/60000] 损失: 0.586820
# 训练轮次: 3 [28800/60000] 损失: 0.304470
# 训练轮次: 3 [32000/60000] 损失: 0.281591
# 训练轮次: 3 [35200/60000] 损失: 0.526238
# 训练轮次: 3 [38400/60000] 损失: 0.180496
# 训练轮次: 3 [41600/60000] 损失: 0.119725
# 训练轮次: 3 [44800/60000] 损失: 0.162329
# 训练轮次: 3 [48000/60000] 损失: 0.327912
# 训练轮次: 3 [51200/60000] 损失: 0.103532
# 训练轮次: 3 [54400/60000] 损失: 0.495988
# 训练轮次: 3 [57600/60000] 损失: 0.148368
# ================ 训练轮次: 3 平均损失: 0.303372 ================
#
# 训练轮次: 4 [0/60000] 损失: 0.289309
# 训练轮次: 4 [3200/60000] 损失: 0.115624
# 训练轮次: 4 [6400/60000] 损失: 0.061304
# 训练轮次: 4 [9600/60000] 损失: 0.497952
# 训练轮次: 4 [12800/60000] 损失: 0.254351
# 训练轮次: 4 [16000/60000] 损失: 0.386651
# 训练轮次: 4 [19200/60000] 损失: 0.488216
# 训练轮次: 4 [22400/60000] 损失: 0.189480
# 训练轮次: 4 [25600/60000] 损失: 0.461837
# 训练轮次: 4 [28800/60000] 损失: 0.231804
# 训练轮次: 4 [32000/60000] 损失: 0.172884
# 训练轮次: 4 [35200/60000] 损失: 0.345843
# 训练轮次: 4 [38400/60000] 损失: 0.110948
# 训练轮次: 4 [41600/60000] 损失: 0.187981
# 训练轮次: 4 [44800/60000] 损失: 0.335855
# 训练轮次: 4 [48000/60000] 损失: 0.126505
# 训练轮次: 4 [51200/60000] 损失: 0.336344
# 训练轮次: 4 [54400/60000] 损失: 0.345916
# 训练轮次: 4 [57600/60000] 损失: 0.195856
# ================ 训练轮次: 4 平均损失: 0.264347 ================
#
# 训练轮次: 5 [0/60000] 损失: 0.080330
# 训练轮次: 5 [3200/60000] 损失: 0.326997
# 训练轮次: 5 [6400/60000] 损失: 0.062166
# 训练轮次: 5 [9600/60000] 损失: 0.144844
# 训练轮次: 5 [12800/60000] 损失: 0.310146
# 训练轮次: 5 [16000/60000] 损失: 0.163296
# 训练轮次: 5 [19200/60000] 损失: 0.100351
# 训练轮次: 5 [22400/60000] 损失: 0.287551
# 训练轮次: 5 [25600/60000] 损失: 0.216516
# 训练轮次: 5 [28800/60000] 损失: 0.163728
# 训练轮次: 5 [32000/60000] 损失: 0.084566
# 训练轮次: 5 [35200/60000] 损失: 0.453118
# 训练轮次: 5 [38400/60000] 损失: 0.487368
# 训练轮次: 5 [41600/60000] 损失: 0.301584
# 训练轮次: 5 [44800/60000] 损失: 0.083540
# 训练轮次: 5 [48000/60000] 损失: 0.186643
# 训练轮次: 5 [51200/60000] 损失: 0.417346
# 训练轮次: 5 [54400/60000] 损失: 0.187283
# 训练轮次: 5 [57600/60000] 损失: 0.129377
# ================ 训练轮次: 5 平均损失: 0.233892 ================
