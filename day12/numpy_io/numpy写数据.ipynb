# %%
import numpy as np

# %%
with open('names.csv', 'w') as f:
    names = ['Alice', 'Bob', 'Charlie','David']
    ages = [20, 30, 40, 50]
    f.write(','.join(names) + '\n')
    f.write(','.join(str(age) for age in ages) + '\n')
    f.close()
